# %% [markdown]
# 1. What does RGBA stand for?
#
# 2. From the Pillow module, how do you get the RGBA value of any images?
#
# 3. What is a box tuple, and how does it work?
#
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
#
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
#
# 6. After making changes to an Image object, how could you save it as an image file?
#
# 7. What module contains Pillow’s shape-drawing code?
#
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# 1. What does RGBA stand for?

# %% [markdown]
# Ans.
# An RGBA value is a tuple of 4 integers, each ranging from 0 to 255. The four integers correspond to the amount of red, green, blue, and alpha (transparency) in the color.
#
# RGBA color values are an extension of RGB color values with an alpha channel - which specifies the opacity for a color. An RGBA color value is specified with: rgba(red, green, blue, alpha). The alpha parameter is a number between 0.0 (fully transparent) and 1.0 (fully opaque).

# %% [markdown]
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %% [raw]
# Ans.

# %%
from IPython.display import Image
Image(filename='image.png')

# %%
from PIL import Image
  
img = Image.open('image.png')
rgba = img.convert("RGBA")
datas = rgba.getdata()
  
newData = []
for item in datas:
    if item[0] == 0 and item[1] == 0 and item[2] == 0:  # finding black colour by its RGB value
        # storing a transparent value when we find a black colour
        newData.append((255, 255, 255, 0))
    else:
        newData.append(item)  # other colours remain unchanged
  
rgba.putdata(newData)
rgba.save("transparent_image.png", "PNG")

# %%
from IPython.display import Image
Image(filename='transparent_image.png')

# %% [markdown]
# 3. What is a box tuple, and how does it work?

# %% [markdown]
# Ans. A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively

# %% [markdown]
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %% [markdown]
# Ans.

# %%
from IPython.display import Image
Image(filename='image.png')

# %% [markdown]
# image.size is a tuple of two integers, the width and the height.

# %% [markdown]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# Ans. imageObj.crop((0, 50, 50, 50)). Notice that you are passing a box tuple to
# crop(), not four separate integer arguments.

# %% [markdown]
# 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# Ans. Call the imageObj.save('image.png') method of the Image object

# %% [markdown]
# 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# Ans. The ImageDraw module contains code to draw on images.

# %% [markdown]
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# Ans. ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function.
